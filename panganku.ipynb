# %%
import pandas as pd
import json

# Load JSON file (as list of dicts)
with open('nutrisi_data.json') as f:
    data = json.load(f)

clean_data = [row for row in data if isinstance(row, dict)]

# Convert to DataFrame
df = pd.DataFrame(clean_data)

print(df)
# Out:
#        Kode                                     Nama          Nama Latin  \
# 0     GP053                             Abon haruwan
# 1     GP054                                Abon ikan
# 2     DR001  Akar tonjong, segar (Lotus root, fresh)    Nelumbo nucifera
# 3     DR002                          Ale,toge, segar  Acacia leucophloea
# 4     ER001          Alpukat, segar (Avocado, fresh)    Persea americana
# ...     ...                                      ...                 ...
# 1141  AP114                                   Yangko
# 1142  JP011                           Yoghurt, segar
# 1143  NR024              Pala, biji, kering (Nutmeg)  Myristica fragrant
# 1144  JP006                               Susu bubuk
# 1145  AP016                        Tapai ketan hitam
#
#                     Asal               Kelompok                Tipe  \
# 0     Kalimantan Selatan  Ikan/Kerang/Udang dll  Olahan (Processed)
# 1                         Ikan/Kerang/Udang dll  Olahan (Processed)
# ...

# %%
clean_data = [row for row in data if not isinstance(row, dict)]

# %%
clean_data
# Out:
# [None, None, None]
